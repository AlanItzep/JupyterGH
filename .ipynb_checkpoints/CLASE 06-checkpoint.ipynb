# %% [markdown]
# # Scikit Learn VI
# ---

# %% [markdown]
# ## Ensamble

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingClassifier
# Out:
# C:\Users\alter\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
diabetes = pd.read_csv('https://goo.gl/CTq1hK', header = None)

# %%
diabetes.columns = ["num_preg", "glucose_conc", "diastolic_bp", "thickness", "insulin", "bmi", "diab_pred", "age", "diabetes"]

# %%
X = diabetes.drop("diabetes", 1)
y = diabetes["diabetes"]

# %%
X_train, X_test,y_train, y_test = train_test_split(X,y,stratify=y,test_size=0.3,random_state=1)

# %%
DTC = DecisionTreeClassifier(random_state=1)

# %%
print("Estimación del set de Validación usando DTC")
print(cross_val_score(DTC, X_train,y_train,cv=5,scoring='roc_auc').mean())
# Out:
# Estimación del set de Validación usando DTC
# 0.6891932534037798

# %%
DTC.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=1,
#             splitter='best')

# %%
y_test_pred = DTC.predict_proba(X_test)

# %%
print("Metrica AUC del set Test usando DTC")
print(roc_auc_score(y_test,y_test_pred[:,1]))
# Out:
# Metrica AUC del set Test usando DTC
# 0.7062962962962963

# %% [markdown]
# ---
# ## Bagging

# %%
BAGG = BaggingClassifier(base_estimator=DTC, random_state=1)
print("Estimación del set de validación usando BAGG")
print(cross_val_score(BAGG,X_train,y_train,cv=5, scoring='roc_auc').mean())
# Out:
# Estimación del set de validación usando BAGG
# 0.7957884576305629

# %%
BAGG.fit(X_train, y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=1,
#             splitter='best'),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=10, n_jobs=1, oob_score=False,
#          random_state=1, verbose=0, warm_start=False)

# %%
y_test_pred = BAGG.predict_proba(X_test)

# %%
print("Métrica AUC dle set de Test usando BAGG")
print(roc_auc_score(y_test,y_test_pred[:,1]))
# Out:
# Métrica AUC dle set de Test usando BAGG
# 0.7853497942386831

# %% [markdown]
# ---
# ## Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
BOOS = AdaBoostClassifier(random_state=1)

# %%
print("Estimación del set de validación usando BAGG")
print(cross_val_score(BOOS, X_train,y_train, cv= 5, scoring='roc_auc').mean())
# Out:
# Estimación del set de validación usando BAGG
# 0.80578540946962

# %%
BOOS.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=1)

# %%
y_test_pred = BOOS.predict_proba(X_test)

# %%
print("Métrica AUC del set de Test Usando BOOS")
print(roc_auc_score(y_test,y_test_pred[:,1]))
# Out:
# Métrica AUC del set de Test Usando BOOS
# 0.8114814814814816

# %% [markdown]
# ---
# ## Voting

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
KNN = KNeighborsClassifier(n_neighbors=2)

# %%
LR = LogisticRegression(random_state=1)

# %%
VOTI = VotingClassifier(estimators=[("DTC",DTC),("LR", LR),("KNN", KNN)], voting='soft')

# %%
VOTI.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('DTC', DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_lea...owski',
#            metric_params=None, n_jobs=1, n_neighbors=2, p=2,
#            weights='uniform'))],
#          flatten_transform=None, n_jobs=1, voting='soft', weights=None)

# %%
y_test_pred= VOTI.predict_proba(X_test)

# %%
print("Métrica AUC del set de Test usando Voting")
print(roc_auc_score(y_test, y_test_pred[:,1]))
# Out:
# Métrica AUC del set de Test usando Voting
# 0.7870781893004114

# %% [markdown]
# ---
# ## Visualización básica de series de tiempo

# %%
import pandas as pd
import numpy as np

# %%
print(pd.__version__,"Versión de Pandas")
# Out:
# 0.23.4 Versión de Pandas

# %%
print(np.__version__,"Versión de NumPy")
# Out:
# 1.15.1 Versión de NumPy

# %%
tiempo = pd.read_csv('https://goo.gl/ccoFyG',skiprows=1)

# %%
tiempo.columns = ['fecha', 'dieta','gimnasio','finanzas']

# %%
tiempo.head()
# Out:
#      fecha  dieta  gimnasio  finanzas
# 0  2004-01    100        31        48
# 1  2004-02     75        26        49
# 2  2004-03     67        24        47
# 3  2004-04     70        22        48
# 4  2004-05     72        22        43

# %%
tiempo.shape
# Out:
# (168, 4)

# %%
tiempo.dtypes
# Out:
# fecha       object
# dieta        int64
# gimnasio     int64
# finanzas     int64
# dtype: object

# %%
tiempo['fecha'] = pd.to_datetime(tiempo['fecha'])

# %%
tiempo.dtypes
# Out:
# fecha       datetime64[ns]
# dieta                int64
# gimnasio             int64
# finanzas             int64
# dtype: object

# %%
tiempo.head()
# Out:
#        fecha  dieta  gimnasio  finanzas
# 0 2004-01-01    100        31        48
# 1 2004-02-01     75        26        49
# 2 2004-03-01     67        24        47
# 3 2004-04-01     70        22        48
# 4 2004-05-01     72        22        43

# %%
tiempo.set_index('fecha',inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# La paleta de la grafica  se escoje del sitio de matplotlib.

# %%
tiempo[['dieta']].plot(figsize=(16,8), color='royalblue', linewidth=2, fontsize=14)
plt.xlabel('Años', fontsize=14);

# %%
tiempo[['gimnasio']].plot(figsize=(16,8), color='darkorange', linewidth=2,fontsize=14)
plt.xlabel('Años', fontsize=14);

# %%
tiempo[['finanzas']].plot(figsize=(16,8),color="g",linewidth=2,fontsize=14)
plt.xlabel('Años', fontsize=14);

# %%
tiempo["dieta"].rolling(12).mean().plot(figsize=(16,8),color = 'royalblue',linewidth=2,fontsize=14)
plt.xlabel('Años', fontsize=14);

# %%
tiempo["dieta"].rolling(12).mean().plot(figsize=(16,8),color='darkorange', linewidth=2,fontsize=14)
plt.xlabel('Años',fontsize=14);

# %%
tiempo["finanzas"].rolling(12).mean().plot(figsize=(16,8),color='g',linewidth=2,fontsize=14)
plt.xlabel('Años',fontsize=14);

# %%
tiempo["dieta"].rolling(12).mean().plot(figsize=(16,8), color='royalblue', linewidth=2,fontsize=14)
tiempo["finanzas"].rolling(12).mean().plot(figsize=(16,8), color='g',linewidth=2,fontsize=14)
plt.xlabel('Años', fontsize=14);

# %%
tiempo["dieta"].diff().plot(figsize=(16,8), color='royalblue',linewidth=2,fontsize=14)
plt.xlabel('Años',fontsize=14);

# %%
tiempo["gimnasio"].diff().plot(figsize=(16,8), color='darkorange',linewidth=2,fontsize=14)
plt.xlabel('Años',fontsize=14);

# %%
tiempo.diff().plot(figsize=(16,8),linewidth=2,fontsize=14)
plt.xlabel('Años',fontsize=14);
