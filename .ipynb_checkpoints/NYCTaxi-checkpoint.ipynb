# %%
import pandas as pd
import numpy as np

# %%
dfg = pd.read_csv('green_tripdata_2015-01.csv')

# %%
dfg.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2     01/01/2015 00:34      01/01/2015 00:38                  N
# 1         2     01/01/2015 00:34      01/01/2015 00:47                  N
# 2         1     01/01/2015 00:34      01/01/2015 00:38                  N
# 3         2     01/01/2015 00:34      01/01/2015 00:38                  N
# 4         2     01/01/2015 00:34      01/01/2015 01:09                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.922592        40.754528         -73.913635
# 1           1        -73.952751        40.677711         -73.981529
# 2           1        -73.843010        40.719055         -73.846581
# 3           1        -73.860825        40.757793         -73.854042
# 4           1        -73.945183        40.783321         -73.989624
#
#    Dropoff_latitude  Passenger_count     ...      Fare_amount  Extra  MTA_tax  \
# 0         40.765522                1     ...              5.0    0.5      0.5
# 1         40.658978                1     ...             12.0    0.5      0.5
# 2         40.711567                1     ...              5.0    0.5      0.5
# 3         40.749821                1     ...              5.0    0.5      0.5
# 4         40.765450                1     ...             24.5    0.5      0.5
#
#    Tip_amount  Tolls_amount  Ehail_fee  improvement_surcharge  Total_amount  \
# 0         0.0           0.0        NaN                    0.3           6.3
# 1         0.0           0.0        NaN                    0.3          13.3
# 2         1.8           0.0        NaN                    0.0           7.8
# 3         0.0           0.0        NaN                    0.3           6.3
# 4         0.0           0.0        NaN                    0.3          25.8
#
#    Payment_type  Trip_type
# 0             2         1.0
# 1             2         1.0
# 2             1         1.0
# 3             2         1.0
# 4             2         1.0
#
# [5 rows x 21 columns]

# %%
dfg.describe()
# Out:
#            VendorID    RateCodeID  Pickup_longitude  Pickup_latitude  \
# count  1.048575e+06  1.048575e+06      1.048575e+06     1.048575e+06
# mean   1.778683e+00  1.098100e+00     -7.381823e+01     4.068497e+01
# std    4.151334e-01  6.505393e-01      2.947688e+00     1.625452e+00
# min    1.000000e+00  1.000000e+00     -7.535131e+01     0.000000e+00
# 25%    2.000000e+00  1.000000e+00     -7.395934e+01     4.070041e+01
# 50%    2.000000e+00  1.000000e+00     -7.394547e+01     4.074686e+01
# 75%    2.000000e+00  1.000000e+00     -7.391782e+01     4.080240e+01
# max    2.000000e+00  9.900000e+01      0.000000e+00     4.291825e+01
#
#        Dropoff_longitude  Dropoff_latitude  Passenger_count  Trip_distance  \
# count       1.048575e+06      1.048575e+06     1.048575e+06   1.048575e+06
# mean       -7.381280e+01      4.068029e+01     1.389390e+00   2.782559e+00
# std         3.009728e+00      1.659509e+00     1.078429e+00   2.952046e+00
# min        -7.543967e+01      0.000000e+00     0.000000e+00   0.000000e+00
# 25%        -7.396799e+01      4.070253e+01     1.000000e+00   1.010000e+00
# 50%        -7.394550e+01      4.074789e+01     1.000000e+00   1.830000e+00
# 75%        -7.391185e+01      4.079070e+01     1.000000e+00   3.540000e+00
# max         0.000000e+00      4.291817e+01     9.000000e+00   8.304000e+02
#
#         Fare_amount         Extra       MTA_tax    Tip_amount  Tolls_amount  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.173290e+01  3.427971e-01  4.865826e-01  1.116572e+00  9.529348e-02
# std    9.551922e+00  3.605977e-01  8.480691e-02  3.804000e+00  1.167153e+00
# min   -4.000000e+02 -1.000000e+00 -5.000000e-01 -1.450000e+01 -1.816000e+01
# 25%    6.000000e+00  0.000000e+00  5.000000e-01  0.000000e+00  0.000000e+00
# 50%    9.000000e+00  5.000000e-01  5.000000e-01  0.000000e+00  0.000000e+00
# 75%    1.450000e+01  5.000000e-01  5.000000e-01  1.750000e+00  0.000000e+00
# max    8.000000e+02  1.000000e+00  8.000000e-01  4.900000e+02  8.698800e+02
#
#        Ehail_fee  improvement_surcharge  Total_amount  Payment_type  \
# count        0.0           1.048575e+06  1.048575e+06  1.048575e+06
# mean         NaN           2.807908e-01  1.499850e+01  1.561091e+00
# std          NaN           7.344232e-02  9.668206e+02  5.218143e-01
# min          NaN           0.000000e+00 -4.000000e+02  1.000000e+00
# 25%          NaN           3.000000e-01  7.800000e+00  1.000000e+00
# 50%          NaN           3.000000e-01  1.080000e+01  2.000000e+00
# 75%          NaN           3.000000e-01  1.700000e+01  2.000000e+00
# max          NaN           3.000000e-01  9.899704e+05  5.000000e+00
#
#          Trip_type
# count  1.048570e+06
# mean   1.022894e+00
# std    1.495658e-01
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    2.000000e+00

# %%
data_filter = dfg['Pickup_longitude'] != 0

# %%
col = data_filter.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-f1a960c1e598> in <module>
# ----> 1 col = data_filter.columns.tolist()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
for column in col:
  print("{}: {}".format(columns, datafilter[column].isnull().sum()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-d7b50f6f2b9b> in <module>
# ----> 1 col = data_filter.columns.tolist()
#       2 for column in col:
#       3   print("{}: {}".format(columns, datafilter[column].isnull().sum()))
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
dfg.shape
# Out:
# (1048575, 21)

# %%
dfg.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2     01/01/2015 00:34      01/01/2015 00:38                  N
# 1         2     01/01/2015 00:34      01/01/2015 00:47                  N
# 2         1     01/01/2015 00:34      01/01/2015 00:38                  N
# 3         2     01/01/2015 00:34      01/01/2015 00:38                  N
# 4         2     01/01/2015 00:34      01/01/2015 01:09                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.922592        40.754528         -73.913635
# 1           1        -73.952751        40.677711         -73.981529
# 2           1        -73.843010        40.719055         -73.846581
# 3           1        -73.860825        40.757793         -73.854042
# 4           1        -73.945183        40.783321         -73.989624
#
#    Dropoff_latitude  Passenger_count     ...      Fare_amount  Extra  MTA_tax  \
# 0         40.765522                1     ...              5.0    0.5      0.5
# 1         40.658978                1     ...             12.0    0.5      0.5
# 2         40.711567                1     ...              5.0    0.5      0.5
# 3         40.749821                1     ...              5.0    0.5      0.5
# 4         40.765450                1     ...             24.5    0.5      0.5
#
#    Tip_amount  Tolls_amount  Ehail_fee  improvement_surcharge  Total_amount  \
# 0         0.0           0.0        NaN                    0.3           6.3
# 1         0.0           0.0        NaN                    0.3          13.3
# 2         1.8           0.0        NaN                    0.0           7.8
# 3         0.0           0.0        NaN                    0.3           6.3
# 4         0.0           0.0        NaN                    0.3          25.8
#
#    Payment_type  Trip_type
# 0             2         1.0
# 1             2         1.0
# 2             1         1.0
# 3             2         1.0
# 4             2         1.0
#
# [5 rows x 21 columns]

# %%
dfn = dfg.drop(dfg.columns[[16]], axis = 'columns')

# %%
dfn = dfn.dropna()

# %%
dfn.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2     01/01/2015 00:34      01/01/2015 00:38                  N
# 1         2     01/01/2015 00:34      01/01/2015 00:47                  N
# 2         1     01/01/2015 00:34      01/01/2015 00:38                  N
# 3         2     01/01/2015 00:34      01/01/2015 00:38                  N
# 4         2     01/01/2015 00:34      01/01/2015 01:09                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.922592        40.754528         -73.913635
# 1           1        -73.952751        40.677711         -73.981529
# 2           1        -73.843010        40.719055         -73.846581
# 3           1        -73.860825        40.757793         -73.854042
# 4           1        -73.945183        40.783321         -73.989624
#
#    Dropoff_latitude  Passenger_count  Trip_distance  Fare_amount  Extra  \
# 0         40.765522                1           0.88          5.0    0.5
# 1         40.658978                1           3.08         12.0    0.5
# 2         40.711567                1           0.90          5.0    0.5
# 3         40.749821                1           0.85          5.0    0.5
# 4         40.765450                1           4.91         24.5    0.5
#
#    MTA_tax  Tip_amount  Tolls_amount  improvement_surcharge  Total_amount  \
# 0      0.5         0.0           0.0                    0.3           6.3
# 1      0.5         0.0           0.0                    0.3          13.3
# 2      0.5         1.8           0.0                    0.0           7.8
# 3      0.5         0.0           0.0                    0.3           6.3
# 4      0.5         0.0           0.0                    0.3          25.8
#
#    Payment_type  Trip_type
# 0             2         1.0
# 1             2         1.0
# 2             1         1.0
# 3             2         1.0
# 4             2         1.0

# %%
col = dfn.columns.tolist()
for column in col:
  print("{}: {}".format(column, dfn[column].isnull().sum()))
# Out:
# VendorID: 0
# lpep_pickup_datetime: 0
# Lpep_dropoff_datetime: 0
# Store_and_fwd_flag: 0
# RateCodeID: 0
# Pickup_longitude: 0
# Pickup_latitude: 0
# Dropoff_longitude: 0
# Dropoff_latitude: 0
# Passenger_count: 0
# Trip_distance: 0
# Fare_amount: 0
# Extra: 0
# MTA_tax: 0
# Tip_amount: 0
# Tolls_amount: 0
# improvement_surcharge: 0
# Total_amount: 0
# Payment_type: 0
# Trip_type : 0

# %%
dfn.shape
# Out:
# (1048570, 20)

# %%
dfg.describe()
# Out:
#            VendorID    RateCodeID  Pickup_longitude  Pickup_latitude  \
# count  1.048575e+06  1.048575e+06      1.048575e+06     1.048575e+06
# mean   1.778683e+00  1.098100e+00     -7.381823e+01     4.068497e+01
# std    4.151334e-01  6.505393e-01      2.947688e+00     1.625452e+00
# min    1.000000e+00  1.000000e+00     -7.535131e+01     0.000000e+00
# 25%    2.000000e+00  1.000000e+00     -7.395934e+01     4.070041e+01
# 50%    2.000000e+00  1.000000e+00     -7.394547e+01     4.074686e+01
# 75%    2.000000e+00  1.000000e+00     -7.391782e+01     4.080240e+01
# max    2.000000e+00  9.900000e+01      0.000000e+00     4.291825e+01
#
#        Dropoff_longitude  Dropoff_latitude  Passenger_count  Trip_distance  \
# count       1.048575e+06      1.048575e+06     1.048575e+06   1.048575e+06
# mean       -7.381280e+01      4.068029e+01     1.389390e+00   2.782559e+00
# std         3.009728e+00      1.659509e+00     1.078429e+00   2.952046e+00
# min        -7.543967e+01      0.000000e+00     0.000000e+00   0.000000e+00
# 25%        -7.396799e+01      4.070253e+01     1.000000e+00   1.010000e+00
# 50%        -7.394550e+01      4.074789e+01     1.000000e+00   1.830000e+00
# 75%        -7.391185e+01      4.079070e+01     1.000000e+00   3.540000e+00
# max         0.000000e+00      4.291817e+01     9.000000e+00   8.304000e+02
#
#         Fare_amount         Extra       MTA_tax    Tip_amount  Tolls_amount  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.173290e+01  3.427971e-01  4.865826e-01  1.116572e+00  9.529348e-02
# std    9.551922e+00  3.605977e-01  8.480691e-02  3.804000e+00  1.167153e+00
# min   -4.000000e+02 -1.000000e+00 -5.000000e-01 -1.450000e+01 -1.816000e+01
# 25%    6.000000e+00  0.000000e+00  5.000000e-01  0.000000e+00  0.000000e+00
# 50%    9.000000e+00  5.000000e-01  5.000000e-01  0.000000e+00  0.000000e+00
# 75%    1.450000e+01  5.000000e-01  5.000000e-01  1.750000e+00  0.000000e+00
# max    8.000000e+02  1.000000e+00  8.000000e-01  4.900000e+02  8.698800e+02
#
#        Ehail_fee  improvement_surcharge  Total_amount  Payment_type  \
# count        0.0           1.048575e+06  1.048575e+06  1.048575e+06
# mean         NaN           2.807908e-01  1.499850e+01  1.561091e+00
# std          NaN           7.344232e-02  9.668206e+02  5.218143e-01
# min          NaN           0.000000e+00 -4.000000e+02  1.000000e+00
# 25%          NaN           3.000000e-01  7.800000e+00  1.000000e+00
# 50%          NaN           3.000000e-01  1.080000e+01  2.000000e+00
# 75%          NaN           3.000000e-01  1.700000e+01  2.000000e+00
# max          NaN           3.000000e-01  9.899704e+05  5.000000e+00
#
#          Trip_type
# count  1.048570e+06
# mean   1.022894e+00
# std    1.495658e-01
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    2.000000e+00

# %%
dfg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
# VendorID                 1048575 non-null int64
# lpep_pickup_datetime     1048575 non-null object
# Lpep_dropoff_datetime    1048575 non-null object
# Store_and_fwd_flag       1048575 non-null object
# RateCodeID               1048575 non-null int64
# Pickup_longitude         1048575 non-null float64
# Pickup_latitude          1048575 non-null float64
# Dropoff_longitude        1048575 non-null float64
# Dropoff_latitude         1048575 non-null float64
# Passenger_count          1048575 non-null int64
# Trip_distance            1048575 non-null float64
# Fare_amount              1048575 non-null float64
# Extra                    1048575 non-null float64
# MTA_tax                  1048575 non-null float64
# Tip_amount               1048575 non-null float64
# Tolls_amount             1048575 non-null float64
# Ehail_fee                0 non-null float64
# improvement_surcharge    1048575 non-null float64
# Total_amount             1048575 non-null float64
# Payment_type             1048575 non-null int64
# Trip_type                1048570 non-null float64
# dtypes: float64(14), int64(4), object(3)
# memory usage: 168.0+ MB

# %%
from bokeh.plotting import figure, save
p = figure(title="My first plot!")
p
# Out:
# bokeh.plotting.figure.Figure(
#     id='01c5a683-fd2d-456c-8fc6-1904291baa1d',
#     above=[],
#     aspect_scale=1,
#     background_fill_alpha={'value': 1.0},
#     background_fill_color={'value': '#ffffff'},
#     below=[bokeh.models.axes.LinearAxis(
#          id='bed56a99-1ce4-4602-b025-ede27a158eff',
#          axis_label='',
#          axis_label_standoff=5,
#          axis_label_text_align='left',
#          axis_label_text_alpha={'value': 1.0},
#          axis_label_text_baseline='bottom',
#          axis_label_text_color={'value': '#444444'},
#          axis_label_text_font='helvetica',
#          axis_label_text_font_size={'value': '10pt'},
#          axis_label_text_font_style='italic',
#          axis_label_text_line_height=1.2,
#          axis_line_alpha={'value': 1.0},
#          axis_line_cap='butt',
#          axis_line_color={'value': 'black'},
#          axis_line_dash=[],
#          axis_line_dash_offset=0,
#          axis_line_join='bevel',
#          axis_line_width={'value': 1},
#          bounds='auto',
#          fixed_location=None,
#          formatter=bokeh.models.formatters.BasicTickFormatter(
#              id='a12f6490-59e3-4555-a8b4-ac0011b3ab96',
#              js_event_callbacks={},
#              js_property_callbacks={},
#              name=None,
#              power_limit_high=5,
#              power_limit_low=-3,
#              precision='auto',
#              subscribed_events=[],
#              tags=[],
#              use_scientific=True),
#          js_event_callbacks={},
#          js_property_callbacks={},
#          level='overlay',
#          major_label_orientation='horizontal',
#          major_label_overrides={},
#          major_label_standoff=5,
#          major_label_text_align='center',
#          major_label_text_alpha={'value': 1.0},
#          major_label_text_baseline='alphabetic',
#          major_label_text_color={'value': '#444444'},
#          major_label_text_font='helvetica',
#          major_label_text_font_size={'value': '8pt'},
#          major_label_text_font_style='normal',
#          major_label_text_line_height=1.2,
#          major_tick_in=2,
#          major_tick_line_alpha={'value': 1.0},
#          major_tick_line_cap='butt',
#          major_tick_line_color={'value': 'black'},
#          major_tick_line_dash=[],
#          major_tick_line_dash_offset=0,
#          major_tick_line_join='bevel',
#          major_tick_line_width={'value': 1},
#          major_tick_out=6,
#          minor_tick_in=0,
#          minor_tick_line_alpha={'value': 1.0},
#          minor_tick_line_cap='butt',
#          minor_tick_line_color={'value': 'black'},
#          minor_tick_line_dash=[],
#          minor_tick_line_dash_offset=0,
#          minor_tick_line_join='bevel',
#          minor_tick_line_width={'value': 1},
#          minor_tick_out=4,
#          name=None,
#          plot=bokeh.plotting.figure.Figure(id='01c5a683-fd2d-456c-8fc6-1904291baa1d', ...),
#          subscribed_events=[],
#          tags=[],
#          ticker=bokeh.models.tickers.BasicTicker(
#              id='1555175d-c40a-47bc-8536-b184d6b51793',
#              base=10.0,
#              desired_num_ticks=6,
#              js_event_callbacks={},
#              js_property_callbacks={},
#              mantissas=[1, 2, 5],
#              max_interval=None,
#              min_interval=0.0,
#              name=None,
#              num_minor_ticks=5,
#              subscribed_events=[],
#              tags=[]),
#          visible=True,
#          x_range_name='default',
#          y_range_name='default')],
#     border_fill_alpha={'value': 1.0},
#     border_fill_color={'value': '#ffffff'},
#     css_classes=[],
#     disabled=False,
#     extra_x_ranges={},
#     extra_y_ranges={},
#     h_symmetry=True,
#     height=None,
#     hidpi=True,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     left=[bokeh.models.axes.LinearAxis(
#          id='2ee7e527-ccea-4d8f-a06d-bb18521fd986',
#          axis_label='',
#          axis_label_standoff=5,
#          axis_label_text_align='left',
#          axis_label_text_alpha={'value': 1.0},
#          axis_label_text_baseline='bottom',
#          axis_label_text_color={'value': '#444444'},
#          axis_label_text_font='helvetica',
#          axis_label_text_font_size={'value': '10pt'},
#          axis_label_text_font_style='italic',
#          axis_label_text_line_height=1.2,
#          axis_line_alpha={'value': 1.0},
#          axis_line_cap='butt',
#          axis_line_color={'value': 'black'},
#          axis_line_dash=[],
#          axis_line_dash_offset=0,
#          axis_line_join='bevel',
#          axis_line_width={'value': 1},
#          bounds='auto',
#          fixed_location=None,
#          formatter=bokeh.models.formatters.BasicTickFormatter(
#              id='4b708be9-bae4-4a3b-a052-6f20c29d53f9',
#              js_event_callbacks={},
#              js_property_callbacks={},
#              name=None,
#              power_limit_high=5,
#              power_limit_low=-3,
#              precision='auto',
#              subscribed_events=[],
#              tags=[],
#              use_scientific=True),
#          js_event_callbacks={},
#          js_property_callbacks={},
#          level='overlay',
#          major_label_orientation='horizontal',
#          major_label_overrides={},
#          major_label_standoff=5,
#          major_label_text_align='center',
#          major_label_text_alpha={'value': 1.0},
#          major_label_text_baseline='alphabetic',
#          major_label_text_color={'value': '#444444'},
#          major_label_text_font='helvetica',
#          major_label_text_font_size={'value': '8pt'},
#          major_label_text_font_style='normal',
#          major_label_text_line_height=1.2,
#          major_tick_in=2,
#          major_tick_line_alpha={'value': 1.0},
#          major_tick_line_cap='butt',
#          major_tick_line_color={'value': 'black'},
#          major_tick_line_dash=[],
#          major_tick_line_dash_offset=0,
#          major_tick_line_join='bevel',
#          major_tick_line_width={'value': 1},
#          major_tick_out=6,
#          minor_tick_in=0,
#          minor_tick_line_alpha={'value': 1.0},
#          minor_tick_line_cap='butt',
#          minor_tick_line_color={'value': 'black'},
#          minor_tick_line_dash=[],
#          minor_tick_line_dash_offset=0,
#          minor_tick_line_join='bevel',
#          minor_tick_line_width={'value': 1},
#          minor_tick_out=4,
#          name=None,
#          plot=bokeh.plotting.figure.Figure(id='01c5a683-fd2d-456c-8fc6-1904291baa1d', ...),
#          subscribed_events=[],
#          tags=[],
#          ticker=bokeh.models.tickers.BasicTicker(
#              id='2adde55b-8bb1-41ef-b119-3558b9996b43',
#              base=10.0,
#              desired_num_ticks=6,
#              js_event_callbacks={},
#              js_property_callbacks={},
#              mantissas=[1, 2, 5],
#              max_interval=None,
#              min_interval=0.0,
#              name=None,
#              num_minor_ticks=5,
#              subscribed_events=[],
#              tags=[]),
#          visible=True,
#          x_range_name='default',
#          y_range_name='default')],
#     lod_factor=10,
#     lod_interval=300,
#     lod_threshold=2000,
#     lod_timeout=500,
#     match_aspect=False,
#     min_border=5,
#     min_border_bottom=None,
#     min_border_left=None,
#     min_border_right=None,
#     min_border_top=None,
#     name=None,
#     outline_line_alpha={'value': 1.0},
#     outline_line_cap='butt',
#     outline_line_color={'value': '#e5e5e5'},
#     outline_line_dash=[],
#     outline_line_dash_offset=0,
#     outline_line_join='bevel',
#     outline_line_width={'value': 1},
#     output_backend='canvas',
#     plot_height=600,
#     plot_width=600,
#     renderers=[bokeh.models.axes.LinearAxis(
#          id='bed56a99-1ce4-4602-b025-ede27a158eff',
#          axis_label='',
#          axis_label_standoff=5,
#          axis_label_text_align='left',
#          axis_label_text_alpha={'value': 1.0},
#          axis_label_text_baseline='bottom',
#          axis_label_text_color={'value': '#444444'},
#          axis_label_text_font='helvetica',
#          axis_label_text_font_size={'value': '10pt'},
#          axis_label_text_font_style='italic',
#          axis_label_text_line_height=1.2,
#          axis_line_alpha={'value': 1.0},
#          axis_line_cap='butt',
#          axis_line_color={'value': 'black'},
#          axis_line_dash=[],
#          axis_line_dash_offset=0,
#          axis_line_join='bevel',
#          axis_line_width={'value': 1},
#          bounds='auto',
#          fixed_location=None,
#          formatter=bokeh.models.formatters.BasicTickFormatter(
#              id='a12f6490-59e3-4555-a8b4-ac0011b3ab96',
#              js_event_callbacks={},
#              js_property_callbacks={},
#              name=None,
#              power_limit_high=5,
#              power_limit_low=-3,
#              precision='auto',
#              subscribed_events=[],
#              tags=[],
#              use_scientific=True),
#          js_event_callbacks={},
#          js_property_callbacks={},
#          level='overlay',
#          major_label_orientation='horizontal',
#          major_label_overrides={},
#          major_label_standoff=5,
#          major_label_text_align='center',
#          major_label_text_alpha={'value': 1.0},
#          major_label_text_baseline='alphabetic',
#          major_label_text_color={'value': '#444444'},
#          major_label_text_font='helvetica',
#          major_label_text_font_size={'value': '8pt'},
#          major_label_text_font_style='normal',
#          major_label_text_line_height=1.2,
#          major_tick_in=2,
#          major_tick_line_alpha={'value': 1.0},
#          major_tick_line_cap='butt',
#          major_tick_line_color={'value': 'black'},
#          major_tick_line_dash=[],
#          major_tick_line_dash_offset=0,
#          major_tick_line_join='bevel',
#          major_tick_line_width={'value': 1},
#          major_tick_out=6,
#          minor_tick_in=0,
#          minor_tick_line_alpha={'value': 1.0},
#          minor_tick_line_cap='butt',
#          minor_tick_line_color={'value': 'black'},
#          minor_tick_line_dash=[],
#          minor_tick_line_dash_offset=0,
#          minor_tick_line_join='bevel',
#          minor_tick_line_width={'value': 1},
#          minor_tick_out=4,
#          name=None,
#          plot=bokeh.plotting.figure.Figure(id='01c5a683-fd2d-456c-8fc6-1904291baa1d', ...),
#          subscribed_events=[],
#          tags=[],
#          ticker=bokeh.models.tickers.BasicTicker(
#              id='1555175d-c40a-47bc-8536-b184d6b51793',
#              base=10.0,
#              desired_num_ticks=6,
#              js_event_callbacks={},
#              js_property_callbacks={},
#              mantissas=[1, 2, 5],
#              max_interval=None,
#              min_interval=0.0,
#              name=None,
#              num_minor_ticks=5,
#              subscribed_events=[],
#              tags=[]),
#          visible=True,
#          x_range_name='default',
#          y_range_name='default'),
#      bokeh.models.grids.Grid(
#          id='345314cf-33d1-453b-bdc0-c43384a95818',
#          band_fill_alpha={'value': 0},
#          band_fill_color={'value': None},
#          bounds='auto',
#          dimension=0,
#          grid_line_alpha={'value': 1.0},
#          grid_line_cap='butt',
#          grid_line_color={'value': '#e5e5e5'},
#          grid_line_dash=[],
#          grid_line_dash_offset=0,
#          grid_line_join='bevel',
#          grid_line_width={'value': 1},
#          js_event_callbacks={},
#          js_property_callbacks={},
#          level='underlay',
#          minor_grid_line_alpha={'value': 1.0},
#          minor_grid_line_cap='butt',
#          minor_grid_line_color={'value': None},
#          minor_grid_line_dash=[],
#          minor_grid_line_dash_offset=0,
#          minor_grid_line_join='bevel',
#          minor_grid_line_width={'value': 1},
#          name=None,
#          plot=bokeh.plotting.figure.Figure(id='01c5a683-fd2d-456c-8fc6-1904291baa1d', ...),
#          subscribed_events=[],
#          tags=[],
#          ticker=bokeh.models.tickers.BasicTicker(
#              id='1555175d-c40a-47bc-8536-b184d6b51793',
#              base=10.0,
#              desired_num_ticks=6,
#              js_event_callbacks={},
#              js_property_callbacks={},
#              mantissas=[1, 2, 5],
#              max_interval=None,
#              min_interval=0.0,
#              name=None,
#              num_minor_ticks=5,
#              subscribed_events=[],
#              tags=[]),
#          visible=True,
#          x_range_name='default',
#          y_range_name='default'),
#      bokeh.models.axes.LinearAxis(
#          id='2ee7e527-ccea-4d8f-a06d-bb18521fd986',
#          axis_label='',
#          axis_label_standoff=5,
#          axis_label_text_align='left',
#          axis_label_text_alpha={'value': 1.0},
#          axis_label_text_baseline='bottom',
#          axis_label_text_color={'value': '#444444'},
#          axis_label_text_font='helvetica',
#          axis_label_text_font_size={'value': '10pt'},
#          axis_label_text_font_style='italic',
#          axis_label_text_line_height=1.2,
#          axis_line_alpha={'value': 1.0},
#          axis_line_cap='butt',
#          axis_line_color={'value': 'black'},
#          axis_line_dash=[],
#          axis_line_dash_offset=0,
#          axis_line_join='bevel',
#          axis_line_width={'value': 1},
#          bounds='auto',
#          fixed_location=None,
#          formatter=bokeh.models.formatters.BasicTickFormatter(
#              id='4b708be9-bae4-4a3b-a052-6f20c29d53f9',
#              js_event_callbacks={},
#              js_property_callbacks={},
#              name=None,
#              power_limit_high=5,
#              power_limit_low=-3,
#              precision='auto',
#              subscribed_events=[],
#              tags=[],
#              use_scientific=True),
#          js_event_callbacks={},
#          js_property_callbacks={},
#          level='overlay',
#          major_label_orientation='horizontal',
#          major_label_overrides={},
#          major_label_standoff=5,
#          major_label_text_align='center',
#          major_label_text_alpha={'value': 1.0},
#          major_label_text_baseline='alphabetic',
#          major_label_text_color={'value': '#444444'},
#          major_label_text_font='helvetica',
#          major_label_text_font_size={'value': '8pt'},
#          major_label_text_font_style='normal',
#          major_label_text_line_height=1.2,
#          major_tick_in=2,
#          major_tick_line_alpha={'value': 1.0},
#          major_tick_line_cap='butt',
#          major_tick_line_color={'value': 'black'},
#          major_tick_line_dash=[],
#          major_tick_line_dash_offset=0,
#          major_tick_line_join='bevel',
#          major_tick_line_width={'value': 1},
#          major_tick_out=6,
#          minor_tick_in=0,
#          minor_tick_line_alpha={'value': 1.0},
#          minor_tick_line_cap='butt',
#          minor_tick_line_color={'value': 'black'},
#          minor_tick_line_dash=[],
#          minor_tick_line_dash_offset=0,
#          minor_tick_line_join='bevel',
#          minor_tick_line_width={'value': 1},
#          minor_tick_out=4,
#          name=None,
#          plot=bokeh.plotting.figure.Figure(id='01c5a683-fd2d-456c-8fc6-1904291baa1d', ...),
#          subscribed_events=[],
#          tags=[],
#          ticker=bokeh.models.tickers.BasicTicker(
#              id='2adde55b-8bb1-41ef-b119-3558b9996b43',
#              base=10.0,
#              desired_num_ticks=6,
#              js_event_callbacks={},
#              js_property_callbacks={},
#              mantissas=[1, 2, 5],
#              max_interval=None,
#              min_interval=0.0,
#              name=None,
#              num_minor_ticks=5,
#              subscribed_events=[],
#              tags=[]),
#          visible=True,
#          x_range_name='default',
#          y_range_name='default'),
#      bokeh.models.grids.Grid(
#          id='22f8af0e-8237-4313-a8c1-064ed2551d82',
#          band_fill_alpha={'value': 0},
#          band_fill_color={'value': None},
#          bounds='auto',
#          dimension=1,
#          grid_line_alpha={'value': 1.0},
#          grid_line_cap='butt',
#          grid_line_color={'value': '#e5e5e5'},
#          grid_line_dash=[],
#          grid_line_dash_offset=0,
#          grid_line_join='bevel',
#          grid_line_width={'value': 1},
#          js_event_callbacks={},
#          js_property_callbacks={},
#          level='underlay',
#          minor_grid_line_alpha={'value': 1.0},
#          minor_grid_line_cap='butt',
#          minor_grid_line_color={'value': None},
#          minor_grid_line_dash=[],
#          minor_grid_line_dash_offset=0,
#          minor_grid_line_join='bevel',
#          minor_grid_line_width={'value': 1},
#          name=None,
#          plot=bokeh.plotting.figure.Figure(id='01c5a683-fd2d-456c-8fc6-1904291baa1d', ...),
#          subscribed_events=[],
#          tags=[],
#          ticker=bokeh.models.tickers.BasicTicker(
#              id='2adde55b-8bb1-41ef-b119-3558b9996b43',
#              base=10.0,
#              desired_num_ticks=6,
#              js_event_callbacks={},
#              js_property_callbacks={},
#              mantissas=[1, 2, 5],
#              max_interval=None,
#              min_interval=0.0,
#              name=None,
#              num_minor_ticks=5,
#              subscribed_events=[],
#              tags=[]),
#          visible=True,
#          x_range_name='default',
#          y_range_name='default'),
#      bokeh.models.annotations.BoxAnnotation(
#          id='d06d1c4c-6d4f-4781-a1fc-daffefe403dc',
#          bottom=None,
#          bottom_units='screen',
#          fill_alpha={'value': 0.5},
#          fill_color={'value': 'lightgrey'},
#          js_event_callbacks={},
#          js_property_callbacks={},
#          left=None,
#          left_units='screen',
#          level='overlay',
#          line_alpha={'value': 1.0},
#          line_cap='butt',
#          line_color={'value': 'black'},
#          line_dash=[4, 4],
#          line_dash_offset=0,
#          line_join='bevel',
#          line_width={'value': 2},
#          name=None,
#          plot=None,
#          render_mode='css',
#          right=None,
#          right_units='screen',
#          subscribed_events=[],
#          tags=[],
#          top=None,
#          top_units='screen',
#          visible=True,
#          x_range_name='default',
#          y_range_name='default')],
#     right=[],
#     sizing_mode='fixed',
#     subscribed_events=[],
#     tags=[],
#     title=bokeh.models.annotations.Title(
#         id='d38e4f66-b843-43e9-a8e9-1f70458d024e',
#         align='left',
#         background_fill_alpha={'value': 1.0},
#         background_fill_color={'value': None},
#         border_line_alpha={'value': 1.0},
#         border_line_cap='butt',
#         border_line_color={'value': None},
#         border_line_dash=[],
#         border_line_dash_offset=0,
#         border_line_join='bevel',
#         border_line_width={'value': 1},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         level='annotation',
#         name=None,
#         offset=0,
#         plot=None,
#         render_mode='canvas',
#         subscribed_events=[],
#         tags=[],
#         text='My first plot!',
#         text_alpha={'value': 1.0},
#         text_color={'value': '#444444'},
#         text_font='helvetica',
#         text_font_size={'value': '10pt'},
#         text_font_style='bold',
#         vertical_align='bottom',
#         visible=True),
#     title_location='above',
#     toolbar=bokeh.models.tools.Toolbar(
#         id='5b1efee2-6a9e-4706-9fdf-c23b9ea1f206',
#         active_drag='auto',
#         active_inspect='auto',
#         active_multi=None,
#         active_scroll='auto',
#         active_tap='auto',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         logo='normal',
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         tools=[bokeh.models.tools.PanTool(
#              id='f7943871-aeab-4d76-9b41-494c78f37c00',
#              dimensions='both',
#              js_event_callbacks={},
#              js_property_callbacks={},
#              name=None,
#              subscribed_events=[],
#              tags=[]),
#          bokeh.models.tools.WheelZoomTool(
#              id='46446152-d564-436b-b1b2-53438940fa95',
#              dimensions='both',
#              js_event_callbacks={},
#              js_property_callbacks={},
#              maintain_focus=True,
#              name=None,
#              speed=0.0016666666666666668,
#              subscribed_events=[],
#              tags=[],
#              zoom_on_axis=True),
#          bokeh.models.tools.BoxZoomTool(
#              id='58b4219a-3e75-4529-9805-8ef906f93db4',
#              dimensions='both',
#              js_event_callbacks={},
#              js_property_callbacks={},
#              match_aspect=False,
#              name=None,
#              origin='corner',
#              overlay=bokeh.models.annotations.BoxAnnotation(
#                  id='d06d1c4c-6d4f-4781-a1fc-daffefe403dc',
#                  bottom=None,
#                  bottom_units='screen',
#                  fill_alpha={'value': 0.5},
#                  fill_color={'value': 'lightgrey'},
#                  js_event_callbacks={},
#                  js_property_callbacks={},
#                  left=None,
#                  left_units='screen',
#                  level='overlay',
#                  line_alpha={'value': 1.0},
#                  line_cap='butt',
#                  line_color={'value': 'black'},
#                  line_dash=[4, 4],
#                  line_dash_offset=0,
#                  line_join='bevel',
#                  line_width={'value': 2},
#                  name=None,
#                  plot=None,
#                  render_mode='css',
#                  right=None,
#                  right_units='screen',
#                  subscribed_events=[],
#                  tags=[],
#                  top=None,
#                  top_units='screen',
#                  visible=True,
#                  x_range_name='default',
#                  y_range_name='default'),
#              subscribed_events=[],
#              tags=[]),
#          bokeh.models.tools.SaveTool(
#              id='7671d1b5-397b-4272-8fa1-350ce21e986e',
#              js_event_callbacks={},
#              js_property_callbacks={},
#              name=None,
#              subscribed_events=[],
#              tags=[]),
#          bokeh.models.tools.ResetTool(
#              id='e90a4919-21cc-4650-ae57-d25ee1413f3e',
#              js_event_callbacks={},
#              js_property_callbacks={},
#              name=None,
#              subscribed_events=[],
#              tags=[]),
#          bokeh.models.tools.HelpTool(
#              id='ea2f7905-1aeb-47d6-a628-9224feb8ccee',
#              help_tooltip='Click the question mark to learn more about Bokeh plot tools.',
#              js_event_callbacks={},
#              js_property_callbacks={},
#              name=None,
#              redirect='https://bokeh.pydata.org/en/latest/docs/user_guide/tools.html#built-in-tools',
#              subscribed_events=[],
#              tags=[])]),
#     toolbar_location='right',
#     toolbar_sticky=True,
#     v_symmetry=False,
#     width=None,
#     x_range=bokeh.models.ranges.DataRange1d(
#         id='84bcbe32-3fca-45cb-94e7-64ae903bb431',
#         bounds=None,
#         callback=None,
#         default_span=2.0,
#         end=None,
#         flipped=False,
#         follow=None,
#         follow_interval=None,
#         js_event_callbacks={},
#         js_property_callbacks={},
#         max_interval=None,
#         min_interval=None,
#         name=None,
#         names=[],
#         range_padding=0.1,
#         range_padding_units='percent',
#         renderers=[],
#         start=None,
#         subscribed_events=[],
#         tags=[]),
#     x_scale=bokeh.models.scales.LinearScale(
#         id='f1718e5a-2288-4500-952f-af3cb87912a1',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         subscribed_events=[],
#         tags=[]),
#     y_range=bokeh.models.ranges.DataRange1d(
#         id='78b3f169-bb76-406f-bbcd-c6f29346be2b',
#         bounds=None,
#         callback=None,
#         default_span=2.0,
#         end=None,
#         flipped=False,
#         follow=None,
#         follow_interval=None,
#         js_event_callbacks={},
#         js_property_callbacks={},
#         max_interval=None,
#         min_interval=None,
#         name=None,
#         names=[],
#         range_padding=0.1,
#         range_padding_units='percent',
#         renderers=[],
#         start=None,
#         subscribed_events=[],
#         tags=[]),
#     y_scale=bokeh.models.scales.LinearScale(
#         id='c5bc2fdc-e12f-4d2d-8ed3-2a401ff22c5e',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         subscribed_events=[],
#         tags=[]))

# %%
x_coords = [0,1,2,3,4]
y_coords = [5,4,1,2,0]

# %%
p.circle(x=x_coords, y = y_coords, size = 10, color = "red")
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='5f93e10d-9280-49a7-875f-bd1eccbbcb51',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='d8e0f097-85c0-4888-a2ae-b2fdff663aaf',
#         callback=None,
#         data={'x': [0, 1, 2, 3, 4], 'y': [5, 4, 1, 2, 0]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='8141803b-aa6d-4caf-9b08-9100991c63db',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='0f7f94b2-21de-4b71-b95c-207a59f746b8',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Circle(
#         id='58fb5822-1695-4f68-b780-759ca759077a',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'value': 'red'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'value': 'red'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 10, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Circle(
#         id='025542f2-2c30-4acd-963b-76874d16e54b',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 10, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='50e1db5e-516d-479b-94c2-746071d45ba2',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='d8e0f097-85c0-4888-a2ae-b2fdff663aaf',
#             callback=None,
#             data={'x': [0, 1, 2, 3, 4], 'y': [5, 4, 1, 2, 0]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='8141803b-aa6d-4caf-9b08-9100991c63db',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='0f7f94b2-21de-4b71-b95c-207a59f746b8',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
#C:\Users\alter\Desktop
outputfp = r"/Users/alter/Desktop/points.htmls"

# %%
save(obj = p, filename = outputfp)
# Out:
# 'C:\\Users\\alter\\Desktop\\points.htmls'

# %%
import geopandas as gpd

# %%
points_fp = r"/Users/alter/Documents/Barcelona/La Salle/Asignaturas/Data Mining/JupyterGH/green_tripdata_2015-02.csv"

# Read the data
points = gpd.read_file(points_fp)

# %%
points.head()

# %%
p = figure(title="A map of address points from a Shapefile")
