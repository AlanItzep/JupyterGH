# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Preprocessing
# * Green taxis datasets.
# * Months:
#         Jannuary
#         February

# %%
df_j = pd.read_csv('green_tripdata_2015-01.csv')

# %% [markdown]
# We aggregate ',,' in the text plain of the document, because initially we see two columns at the final of the table which create problems, so with this movement we aggregate anoter tittles and with this then we will erase this columns.

# %%
df_f = pd.read_csv('green_tripdata_2015-02.csv')

# %% [markdown]
# Check point 1:

# %%
df_jn = df_j
df_fb = df_f

# %%
df_jn.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-01-01 00:34:00   2015-01-01 00:38:00                  N
# 1         2  2015-01-01 00:34:00   2015-01-01 00:47:00                  N
# 2         1  2015-01-01 00:34:00   2015-01-01 00:38:00                  N
# 3         2  2015-01-01 00:34:00   2015-01-01 00:38:00                  N
# 4         2  2015-01-01 00:34:00   2015-01-01 01:09:00                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.922592        40.754528         -73.913635
# 1           1        -73.952751        40.677711         -73.981529
# 2           1        -73.843010        40.719055         -73.846581
# 3           1        -73.860825        40.757793         -73.854042
# 4           1        -73.945183        40.783321         -73.989624
#
#    Dropoff_latitude  Passenger_count    ...      Fare_amount  Extra  MTA_tax  \
# ...

# %%
df_jn['lpep_pickup_datetime'] = pd.to_datetime(df_jn['lpep_pickup_datetime'], format = '%d/%m/%Y %H:%M')

# %%
df_jn['Lpep_dropoff_datetime'] = pd.to_datetime(df_jn['Lpep_dropoff_datetime'], format = '%d/%m/%Y %H:%M')

# %%
df_jn.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-01-01 00:34:00   2015-01-01 00:38:00                  N
# 1         2  2015-01-01 00:34:00   2015-01-01 00:47:00                  N
# 2         1  2015-01-01 00:34:00   2015-01-01 00:38:00                  N
# 3         2  2015-01-01 00:34:00   2015-01-01 00:38:00                  N
# 4         2  2015-01-01 00:34:00   2015-01-01 01:09:00                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.922592        40.754528         -73.913635
# 1           1        -73.952751        40.677711         -73.981529
# 2           1        -73.843010        40.719055         -73.846581
# 3           1        -73.860825        40.757793         -73.854042
# 4           1        -73.945183        40.783321         -73.989624
#
#    Dropoff_latitude  Passenger_count    ...      Fare_amount  Extra  MTA_tax  \
# ...

# %%
df_fb.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-02-01 00:00:01   2015-02-01 00:18:27                  N
# 1         2  2015-02-01 00:00:06   2015-02-01 00:05:26                  N
# 2         2  2015-02-01 00:00:09   2015-02-01 00:25:24                  N
# 3         2  2015-02-01 00:00:21   2015-02-01 00:07:10                  N
# 4         2  2015-02-01 00:00:13   2015-02-01 00:09:51                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.961990        40.715862         -74.012161
# 1           1        -73.945648        40.807812         -73.952202
# 2           1        -73.954819        40.820702         -73.998833
# 3           1        -73.916412        40.761032         -73.908440
# 4           5        -73.914131        40.836639         -73.912621
#
#    Dropoff_latitude  Passenger_count     ...       MTA_tax  Tip_amount  \
# ...

# %%
df_fb['lpep_pickup_datetime'] = pd.to_datetime(df_fb['lpep_pickup_datetime'])

# %%
df_fb['Lpep_dropoff_datetime'] = pd.to_datetime(df_fb['Lpep_dropoff_datetime'])

# %%
df_fb.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-02-01 00:00:01   2015-02-01 00:18:27                  N
# 1         2  2015-02-01 00:00:06   2015-02-01 00:05:26                  N
# 2         2  2015-02-01 00:00:09   2015-02-01 00:25:24                  N
# 3         2  2015-02-01 00:00:21   2015-02-01 00:07:10                  N
# 4         2  2015-02-01 00:00:13   2015-02-01 00:09:51                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.961990        40.715862         -74.012161
# 1           1        -73.945648        40.807812         -73.952202
# 2           1        -73.954819        40.820702         -73.998833
# 3           1        -73.916412        40.761032         -73.908440
# 4           5        -73.914131        40.836639         -73.912621
#
#    Dropoff_latitude  Passenger_count     ...       MTA_tax  Tip_amount  \
# ...

# %%
df_jn = df_jn.drop(['Ehail_fee'],axis=1)
df_fb = df_fb.drop(['Ehail_fee'],axis=1)
df_fb = df_fb.drop(['Unnamed: 21'],axis=1)
df_fb = df_fb.drop(['Unnamed: 22'],axis=1)

# %%
df_jn.shape
# Out:
# (1048575, 20)

# %%
df_fb.shape
# Out:
# (1574830, 20)

# %%
df_concat = pd.concat([df_jn, df_fb],sort=True)
df_concat.index = range(df_concat.shape[0])
df_concat.shape
# Out:
# (2623405, 20)

# %%
df_concat.head()
# Out:
#    Dropoff_latitude  Dropoff_longitude  Extra  Fare_amount  \
# 0         40.765522         -73.913635    0.5          5.0
# 1         40.658978         -73.981529    0.5         12.0
# 2         40.711567         -73.846581    0.5          5.0
# 3         40.749821         -73.854042    0.5          5.0
# 4         40.765450         -73.989624    0.5         24.5
#
#   Lpep_dropoff_datetime  MTA_tax  Passenger_count  Payment_type  \
# 0   2015-01-01 00:38:00      0.5                1             2
# 1   2015-01-01 00:47:00      0.5                1             2
# 2   2015-01-01 00:38:00      0.5                1             1
# 3   2015-01-01 00:38:00      0.5                1             2
# 4   2015-01-01 01:09:00      0.5                1             2
#
#    Pickup_latitude  Pickup_longitude  RateCodeID Store_and_fwd_flag  \
# 0        40.754528        -73.922592           1                  N
# 1        40.677711        -73.952751           1                  N
# ...

# %%
df_concat = df_concat[['VendorID','lpep_pickup_datetime','Lpep_dropoff_datetime','Store_and_fwd_flag','RateCodeID','Pickup_longitude','Pickup_latitude','Dropoff_longitude','Dropoff_latitude','Passenger_count','Trip_distance','Fare_amount','Extra','MTA_tax','Tip_amount','Tolls_amount','improvement_surcharge','Total_amount','Payment_type','Trip_type']]
df_concat.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2015-01-01 00:34:00   2015-01-01 00:38:00                  N
# 1         2  2015-01-01 00:34:00   2015-01-01 00:47:00                  N
# 2         1  2015-01-01 00:34:00   2015-01-01 00:38:00                  N
# 3         2  2015-01-01 00:34:00   2015-01-01 00:38:00                  N
# 4         2  2015-01-01 00:34:00   2015-01-01 01:09:00                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.922592        40.754528         -73.913635
# 1           1        -73.952751        40.677711         -73.981529
# 2           1        -73.843010        40.719055         -73.846581
# 3           1        -73.860825        40.757793         -73.854042
# 4           1        -73.945183        40.783321         -73.989624
#
#    Dropoff_latitude  Passenger_count  Trip_distance  Fare_amount  Extra  \
# ...

# %%
df_concat.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# Lpep_dropoff_datetime    datetime64[ns]
# Store_and_fwd_flag               object
# RateCodeID                        int64
# Pickup_longitude                float64
# Pickup_latitude                 float64
# Dropoff_longitude               float64
# Dropoff_latitude                float64
# Passenger_count                   int64
# Trip_distance                   float64
# Fare_amount                     float64
# Extra                           float64
# MTA_tax                         float64
# Tip_amount                      float64
# Tolls_amount                    float64
# improvement_surcharge           float64
# Total_amount                    float64
# Payment_type                      int64
# Trip_type                       float64
# dtype: object

# %% [markdown]
# Checkpoint 2

# %%
df = df_concat

# %%
df.shape
#2623405
# Out:
# (2623405, 20)

# %% [markdown]
# ### To delete:
# All rows in columns Pickup_longitude Pickup_latitude  Dropoff_longitude Dropoff_latitude with value 0.

# %%
col = df.columns.tolist()

# %%
for column in col:
  print("{}: {}".format(column, df[column].isnull().sum()))
# Out:
# VendorID: 0
# lpep_pickup_datetime: 0
# Lpep_dropoff_datetime: 0
# Store_and_fwd_flag: 0
# RateCodeID: 0
# Pickup_longitude: 0
# Pickup_latitude: 0
# Dropoff_longitude: 0
# Dropoff_latitude: 0
# Passenger_count: 0
# Trip_distance: 0
# Fare_amount: 0
# Extra: 0
# MTA_tax: 0
# Tip_amount: 0
# Tolls_amount: 0
# improvement_surcharge: 0
# Total_amount: 0
# Payment_type: 0
# Trip_type: 7

# %%
col = df.columns.tolist()

for column in col:
  print("{}: {}".format(column, df[column].unique()))
# Out:
# VendorID: [2 1]
# lpep_pickup_datetime: ['2015-01-01T00:34:00.000000000' '2015-01-01T00:35:00.000000000'
#  '2015-01-01T00:36:00.000000000' ... '2015-02-28T23:20:58.000000000'
#  '2015-02-28T23:44:08.000000000' '2015-02-28T23:47:56.000000000']
# Lpep_dropoff_datetime: ['2015-01-01T00:38:00.000000000' '2015-01-01T00:47:00.000000000'
#  '2015-01-01T01:09:00.000000000' ... '2015-03-01T00:05:26.000000000'
#  '2015-02-28T23:54:37.000000000' '2015-02-28T23:51:48.000000000']
# Store_and_fwd_flag: ['N' 'Y']
# RateCodeID: [ 1  5  2  3  4  6 99]
# Pickup_longitude: [-73.92259216 -73.95275116 -73.84300995 ... -74.03020477 -74.00556946
#  -74.0300293 ]
# Pickup_latitude: [40.75452805 40.67771149 40.71905518 ... 40.89931107 40.63294601
#  40.62592697]
# Dropoff_longitude: [-73.91363525 -73.98152924 -73.84658051 ... -73.74378204 -74.03642273
#  -73.721138  ]
# Dropoff_latitude: [40.765522   40.65897751 40.71156693 ... 40.92396545 40.59815598
#  40.88837433]
# ...

# %%
df.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# Lpep_dropoff_datetime    datetime64[ns]
# Store_and_fwd_flag               object
# RateCodeID                        int64
# Pickup_longitude                float64
# Pickup_latitude                 float64
# Dropoff_longitude               float64
# Dropoff_latitude                float64
# Passenger_count                   int64
# Trip_distance                   float64
# Fare_amount                     float64
# Extra                           float64
# MTA_tax                         float64
# Tip_amount                      float64
# Tolls_amount                    float64
# improvement_surcharge           float64
# Total_amount                    float64
# Payment_type                      int64
# Trip_type                       float64
# dtype: object

# %%
df.dropna(inplace = True)

# %% [markdown]
# ## change types:
# lpep_pickup_datetime Lpep_dropoff_datetime Trip_type
#
# ## verify valids quantity of each column
# No negatives:
# Trip_distance Fare_amount Total_amount

# %%
df['Trip_type'] = df['Trip_type'].astype(np.int64)

# %%
df.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# Lpep_dropoff_datetime    datetime64[ns]
# Store_and_fwd_flag               object
# RateCodeID                        int64
# Pickup_longitude                float64
# Pickup_latitude                 float64
# Dropoff_longitude               float64
# Dropoff_latitude                float64
# Passenger_count                   int64
# Trip_distance                   float64
# Fare_amount                     float64
# Extra                           float64
# MTA_tax                         float64
# Tip_amount                      float64
# Tolls_amount                    float64
# improvement_surcharge           float64
# Total_amount                    float64
# Payment_type                      int64
# Trip_type                         int64
# dtype: object

# %%
df['Trip_distance'].describe().round(2)
# Out:
# count    2623398.00
# mean           2.78
# std            2.97
# min            0.00
# 25%            1.01
# 50%            1.82
# 75%            3.53
# max          830.40
# Name: Trip_distance, dtype: float64

# %%
df['Fare_amount'].describe().round(2)
# Out:
# count    2623398.00
# mean          11.95
# std           10.35
# min         -400.00
# 25%            6.00
# 50%            9.00
# 75%           14.50
# max         2084.00
# Name: Fare_amount, dtype: float64

# %%
df = df.loc[df['Fare_amount'] >= 0]

# %%
df['Total_amount'].describe().round(2)
# Out:
# count    2619568.00
# mean          14.73
# std          611.77
# min            0.00
# 25%            7.80
# 50%           11.00
# 75%           17.30
# max       989970.39
# Name: Total_amount, dtype: float64

# %%
df = df.loc[df['Total_amount'] >= 0 ]
df = df.loc[df['Total_amount'] <= 1000]
df.shape
# Out:
# (2619563, 20)

# %%
df['Total_amount'].describe().round(2)
# Out:
# count    2619563.00
# mean          14.35
# std           11.87
# min            0.00
# 25%            7.80
# 50%           11.00
# 75%           17.30
# max          874.18
# Name: Total_amount, dtype: float64

# %%
df.duplicated().sum()
# Out:
# 120

# %%
df.drop_duplicates(inplace = True)

# %%
(df.describe()).round(2)
# Out:
#          VendorID  RateCodeID  Pickup_longitude  Pickup_latitude  \
# count  2619443.00  2619443.00        2619443.00       2619443.00
# mean         1.78        1.10            -73.82            40.69
# std          0.41        0.62              2.88             1.59
# min          1.00        1.00            -77.46             0.00
# 25%          2.00        1.00            -73.96            40.70
# 50%          2.00        1.00            -73.94            40.75
# 75%          2.00        1.00            -73.92            40.80
# max          2.00       99.00              0.00            42.92
#
#        Dropoff_longitude  Dropoff_latitude  Passenger_count  Trip_distance  \
# count         2619443.00        2619443.00       2619443.00     2619443.00
# mean              -73.81             40.68             1.38           2.78
# std                 3.08              1.70             1.07           2.96
# min               -80.84              0.00             0.00           0.00
# ...

# %%
df = df.loc[df['Pickup_longitude'] != 0]

# %%
df = df.loc[df['Pickup_latitude'] != 0]

# %%
df = df.loc[df['Dropoff_longitude'] != 0]

# %%
df = df.loc[df['Dropoff_latitude'] != 0]

# %%
df['RateCodeID'].unique()
# Out:
# array([ 1,  5,  2,  3,  4,  6, 99], dtype=int64)

# %%
df['RateCodeID'].value_counts()
# Out:
# 1     2543597
# 5       58834
# 2        6814
# 3        1752
# 4         925
# 6          41
# 99          4
# Name: RateCodeID, dtype: int64

# %%
df = df.loc[df['RateCodeID'] != 99]
df.shape
# Out:
# (2611963, 20)

# %%
df.describe().round(2)
# Out:
#          VendorID  RateCodeID  Pickup_longitude  Pickup_latitude  \
# count  2611963.00   2611963.0        2611963.00       2611963.00
# mean         1.78         1.1            -73.94            40.75
# std          0.41         0.6              0.04             0.06
# min          1.00         1.0            -77.46            37.80
# 25%          2.00         1.0            -73.96            40.70
# 50%          2.00         1.0            -73.94            40.75
# 75%          2.00         1.0            -73.92            40.80
# max          2.00         6.0            -68.17            42.92
#
#        Dropoff_longitude  Dropoff_latitude  Passenger_count  Trip_distance  \
# count         2611963.00        2611963.00       2611963.00     2611963.00
# mean              -73.93             40.75             1.38           2.78
# std                 0.05              0.06             1.07           2.96
# min               -80.84             35.23             0.00           0.00
# ...

# %% [markdown]
# # Then we will split the dataset
# The principal reason is because it's a good pratice dont work with all the samples, so for this reason and also because we hace a very large dataset.
#
#      total: 2611963
#
#  * 80 % train: 2089570
#  * 20 % test: 522393
#
#  Optionally:
#  * 10 % validation

# %%
df.shape
# Out:
# (2611963, 20)

# %% [markdown]
# Checkpoint 3

# %%
from random import sample
lil_df = df.loc[np.random.choice(df.index, 2089570, replace = False)]
lil_df.shape
# Out:
# (2089570, 20)

# %%
lil_df = lil_df.sort_values(by = 'lpep_pickup_datetime')

# %%
lil_df.reset_index(drop = True, inplace = True)

# %%
lil_df.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2           2015-01-01   2015-01-01 00:18:00                  N
# 1         2           2015-01-01   2015-01-01 00:06:00                  N
# 2         2           2015-01-01   2015-01-01 00:11:00                  N
# 3         2           2015-01-01   2015-01-01 00:15:00                  N
# 4         1           2015-01-01   2015-01-01 00:04:00                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.955200        40.734467         -73.976334
# 1           1        -73.961418        40.714340         -73.961357
# 2           1        -73.939560        40.749886         -73.932854
# 3           1        -73.981468        40.689674         -73.913696
# 4           1        -73.807426        40.700104         -73.806000
#
#    Dropoff_latitude  Passenger_count  Trip_distance  Fare_amount  Extra  \
# ...

# %%
lil_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Checkpoint 4

# %%
df_clean = lil_df

# %%
df_clean.describe()
# Out:
#            VendorID    RateCodeID  Pickup_longitude  Pickup_latitude  \
# count  2.089570e+06  2.089570e+06      2.089570e+06     2.089570e+06
# mean   1.780004e+00  1.095257e+00     -7.393507e+01     4.075110e+01
# std    4.142434e-01  6.003878e-01      4.194988e-02     5.794205e-02
# min    1.000000e+00  1.000000e+00     -7.535131e+01     3.994793e+01
# 25%    2.000000e+00  1.000000e+00     -7.395894e+01     4.070062e+01
# 50%    2.000000e+00  1.000000e+00     -7.394492e+01     4.074705e+01
# 75%    2.000000e+00  1.000000e+00     -7.391716e+01     4.080427e+01
# max    2.000000e+00  6.000000e+00     -6.816718e+01     4.291825e+01
#
#        Dropoff_longitude  Dropoff_latitude  Passenger_count  Trip_distance  \
# count       2.089570e+06      2.089570e+06     2.089570e+06   2.089570e+06
# mean       -7.393455e+01      4.074931e+01     1.383670e+00   2.781477e+00
# std         4.985451e-02      5.868820e-02     1.069790e+00   2.946282e+00
# ...

# %%
df_clean.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# Lpep_dropoff_datetime    datetime64[ns]
# Store_and_fwd_flag               object
# RateCodeID                        int64
# Pickup_longitude                float64
# Pickup_latitude                 float64
# Dropoff_longitude               float64
# Dropoff_latitude                float64
# Passenger_count                   int64
# Trip_distance                   float64
# Fare_amount                     float64
# Extra                           float64
# MTA_tax                         float64
# Tip_amount                      float64
# Tolls_amount                    float64
# improvement_surcharge           float64
# Total_amount                    float64
# Payment_type                      int64
# Trip_type                         int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib import cm

# %%
# %matplotlib inline

# %%
x_coords = df_clean['Pickup_longitude']
y_coords = df_clean['Pickup_latitude']

# %%
#-74.26, 40.50, -73.70, 40.92 
# -75.35131, 39.94793, -70.95729, 42.91825 
west, south, east, north = -74.26, 40.50, -73.70, 40.92 
#Pickup_longitude Pickup_latitude
fig = plt.figure(figsize=(18,18))
ax = fig.add_subplot(111)
m = Basemap(projection='merc', llcrnrlat=south, urcrnrlat=north, llcrnrlon=west, urcrnrlon=east, lat_ts=south, resolution='i')
#m.drawcoastlines()
m.drawmapboundary(fill_color='aqua')
x, y = m(x_coords.values,y_coords.values)
m.hexbin(x, y, gridsize=5000, bins='log', cmap=cm.Spectral_r);#YlOrRd_r /YlGn_r/Spectral_r /seismic
